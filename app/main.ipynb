# %% [markdown]
# # Deep Clustering NoteBook

# %% [markdown]
# L'objectif est de tenter d'implémenter une méthode de deep clustering pour la classification d'image

# %%
from torch.utils.data import DataLoader
from torchvision import datasets
from torchvision.transforms import ToTensor
from run import utils
from devs.vae import VariationalAutoEncoder

# %%
DEVICE = 'cpu'

# %%
data = DataLoader(
    datasets.MNIST(
        './data',
        transform=ToTensor(),
        download=True
    ),
    batch_size=128,
    shuffle=True)

# %%
latent_dims = 2
vae = VariationalAutoEncoder(latent_dims).to(DEVICE)
vae = utils.train(vae, data)

# %%
utils.plot_latent(vae, data)

# %%
latent_dims = 100
vae = VariationalAutoEncoder(latent_dims).to(DEVICE)
vae = utils.train(vae, data)
